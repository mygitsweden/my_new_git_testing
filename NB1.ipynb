# %%
# %sql
select current_timestamp();

# %%
# %sql
select current_catalog();

# %%
# %sql
select ('hello world');

# %%
# %sql
select ('hello world new from mind');

# %%
# %sql
declare name1 string;
set var name1 ='hello';
select name1 as name;

# %%
# %sql
drop temporary variable name1;
